# %%
%%sql -r dataframe_1
CREATE OR REPLACE MCP SERVER TH_DEMO_DB.PUBLIC.THOAD_WRITER_MCP
  FROM SPECIFICATION $$
  {
    "version": 1,
    "tools": [
      {
        "title": "PubMed Search",
        "name": "pubmed-search",
        "identifier": "PUBMED_BIOMEDICAL_RESEARCH_CORPUS.OA_COMM.PUBMED_OA_CKE_SEARCH_SERVICE",
        "type": "CORTEX_SEARCH_SERVICE_QUERY",
        "description": "Search PubMed biomedical and life sciences journal articles"
      },
      {
        "title": "Clinical Trials Search",
        "name": "clinical-trials-search",
        "identifier": "CLINICAL_TRIALS_RESEARCH_DATABASE.CT.CLINICAL_TRIALS_SEARCH_SERVICE",
        "type": "CORTEX_SEARCH_SERVICE_QUERY",
        "description": "Search clinical trials research database for trial information including conditions, phases, and eligibility"
      },
      {
        "title": "Oncology Patient Data",
        "name": "oncology-patient-data",
        "identifier": "TH_DEMO_DB.LIFE_SCIENCES.ONCOLOGY_PATIENT_DATA_SV",
        "type": "CORTEX_ANALYST_MESSAGE",
        "description": "Semantic view containing patient-level information about US cancer patients including disease stage, prior treatment, and biomarkers for cohort selection"
      }
    ]
  }
  $$;

SHOW MCP SERVERS;
